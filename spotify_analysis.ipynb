# %%
# !pip install spotipy

# %%
pip install spotipy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd



load_dotenv()

client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")


client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


artist_name = ["Alan Walker", 'Adele', 'Drake', 'Taylor Swift', 'Ed Sheeran', 'The Weeknd', 'Billie Eilish', 'Dua Lipa', 'Bruno Mars', 'Post Malone', 'Justin Bieber', 'Rihanna', 'Kendrick Lamar', 'Ariana Grande', 'Beyoncé', 'Khalid', 'Camila Cabello', 'Shawn Mendes', 'Cardi B', 'Halsey']
tracks_list = []
for name in artist_name:
    result = sp.search(q='artist:' + name, type='artist', limit=1)
    artist_uri = result['artists']['items'][0]['uri']
    top_tracks = sp.artist_top_tracks(artist_uri, country='US')

    for track in top_tracks['tracks']:
        track_info = {
            'name': track['name'],
            'album': track['album']['name'],
            'release_date': track['album']['release_date'],
            'popularity': track['popularity'],
            'duration_ms': track['duration_ms'],
            'explicit': track['explicit']
        }
        tracks_list.append(track_info)


df_tracks = pd.DataFrame(tracks_list)

file_path = r'Data\top_tracks_adele.csv'
if os.path.exists(file_path):
    print("file exists in the repo")
else:
    df_tracks.to_csv('top_tracks_adele.csv', index=False)
    print("Data saved to top_tracks_adele.csv")


df_tracks
# Out:
# file exists in the repo
#                             name                      album release_date  \
# 0                          Faded            Different World   2018-12-14
# 1                      On My Way            World Of Walker   2021-11-26
# 2                          Alone            Different World   2018-12-14
# 3    Better Off (Alone, Pt. III)                Walkerworld   2023-11-10
# 4                  Alone, Pt. II            World Of Walker   2021-11-26
# ..                           ...                        ...          ...
# 195  Boy With Luv (feat. Halsey)  MAP OF THE SOUL : PERSONA   2019-04-12
# 196                     Gasoline          BADLANDS (Deluxe)   2015-08-28
# 197                       Colors                   BADLANDS   2015-08-28
# 198        Be Kind (with Halsey)      Be Kind (with Halsey)   2020-05-01
# 199                      Control          BADLANDS (Deluxe)   2015-08-28
#
#      popularity  duration_ms  explicit
# ...

# %%
result
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=artist%3AHalsey&type=artist',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=artist%3AHalsey&type=artist',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#     'followers': {'href': None, 'total': 22300136},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#     'id': '26VFTg2z8YR0cCuwLzESi2',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb15136101a0f63f0b2800b9dc',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517415136101a0f63f0b2800b9dc',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17815136101a0f63f0b2800b9dc',
#       'height': 160,
#       'width': 160}],
#     'name': 'Halsey',
# ...

# %%
top_tracks
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#       'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#       'id': '69GGBxA162lTqCwzJG5jLp',
#       'name': 'The Chainsmokers',
#       'type': 'artist',
#       'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#       'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#       'id': '26VFTg2z8YR0cCuwLzESi2',
#       'name': 'Halsey',
#       'type': 'artist',
#       'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
# ...

# %%
tracks_list
# Out:
# [{'name': 'Faded',
#   'album': 'Different World',
#   'release_date': '2018-12-14',
#   'popularity': 80,
#   'duration_ms': 212106,
#   'explicit': False},
#  {'name': 'On My Way',
#   'album': 'World Of Walker',
#   'release_date': '2021-11-26',
#   'popularity': 71,
#   'duration_ms': 193959,
#   'explicit': True},
#  {'name': 'Alone',
#   'album': 'Different World',
#   'release_date': '2018-12-14',
#   'popularity': 76,
#   'duration_ms': 160426,
#   'explicit': False},
#  {'name': 'Better Off (Alone, Pt. III)',
#   'album': 'Walkerworld',
#   'release_date': '2023-11-10',
#   'popularity': 74,
#   'duration_ms': 151702,
#   'explicit': False},
#  {'name': 'Alone, Pt. II',
#   'album': 'World Of Walker',
#   'release_date': '2021-11-26',
#   'popularity': 71,
#   'duration_ms': 179052,
#   'explicit': False},
#  {'name': 'Issues - Alan Walker Remix',
#   'album': 'Issues (Alan Walker Remix)',
#   'release_date': '2017-05-05',
#   'popularity': 57,
#   'duration_ms': 181000,
# ...

# %%
df_tracks.shape
# Out:
# (200, 6)

# %%
df = df_tracks

# %%
df.describe()
# Out:
#        popularity    duration_ms
# count   200.00000     200.000000
# mean     77.21500  219643.690000
# std      12.95135   40817.770073
# min      22.00000  141805.000000
# 25%      74.00000  193486.750000
# 50%      81.00000  216457.000000
# 75%      84.00000  235936.250000
# max      94.00000  386906.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          200 non-null    object
#  1   album         200 non-null    object
#  2   release_date  200 non-null    object
#  3   popularity    200 non-null    int64
#  4   duration_ms   200 non-null    int64
#  5   explicit      200 non-null    bool
# dtypes: bool(1), int64(2), object(3)
# memory usage: 8.1+ KB

# %%
df.isnull().sum()
# Out:
# name            0
# album           0
# release_date    0
# popularity      0
# duration_ms     0
# explicit        0
# dtype: int64

# %%
df.popularity
# Out:
# 0      80
# 1      71
# 2      76
# 3      74
# 4      71
#        ..
# 195    76
# 196    72
# 197    70
# 198    71
# 199    70
# Name: popularity, Length: 200, dtype: int64
